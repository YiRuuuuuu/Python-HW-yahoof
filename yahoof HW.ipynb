# %%
import yfinance as yf
import pandas as pd

# %%
start_date = '1990-01-01'
end_date = '2023-03-03'

# %%
ticker = "AMZN"

# %%
data = yf.download(ticker, period = '10y', interval = '1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2014-04-30  14.9050  15.2280  14.9050  15.2065    15.2065  81772000
# 2014-05-01  15.2065  15.5240  15.2000  15.3945    15.3945  86572000
# 2014-05-02  15.5210  15.6645  15.2155  15.4005    15.4005  79902000
# 2014-05-05  15.3185  15.5115  15.2500  15.5025    15.5025  50398000
# 2014-05-06  15.4765  15.4905  14.8520  14.8690    14.8690  93646000

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
import yfinance as yf
import pandas as pd

# %%
tickers_list = ["2376.tw", "3008.tw", "2330.tw"]

# %%
data = pd.DataFrame(columns = tickers_list)

# %%
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, period = "10y", interval = "1d")['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#               2376.tw      3008.tw    2330.tw
# Date
# 2014-04-29  26.283030  1517.991577  89.196259
# 2014-04-30  25.161190  1474.955811  87.715828
# 2014-05-02  25.374872  1533.641113  87.345726
# 2014-05-05  25.321449  1549.290527  86.605492
# 2014-05-06  25.909081  1564.939819  87.345726

# %%
data.plot(figsize = (10, 7))
plt.legend()
plt.title("Adjusted Close Price", fontsize = 16)
plt.ylabel("Price", fontsize = 14)
plt.xlabel("Year", fontsize = 14)
plt.grid(which = 'major', color = 'k', linestyle = '-.', linewidth = 0.5)
plt.show()
